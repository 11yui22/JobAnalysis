# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt


plt.rcParams['font.sans-serif'] = 'SimHei'
plt.rcParams['axes.unicode_minus'] = False

# %config InlineBackend.figure_format = 'svg'

# %%
job = pd.read_csv('data/job.csv')
job.head()
# Out:
#          job_name    company_name companytype_text providesalary_text  \
# 0            战略专家              美团             上市公司                NaN
# 1  45352-研发项目管理组长  深圳市腾讯计算机系统有限公司             民营公司                NaN
# 2         策略专员-账号    腾讯科技（北京）有限公司             民营公司             1-2万/月
# 3            销售助理            新浪上海               合资             6-8千/月
# 4            城市经理              美团             上市公司           3-4.5万/月
#
#   workarea_text                        jobwelf updatedate  \
# 0        北京-朝阳区                            NaN      10-14
# 1            深圳                            NaN      10-14
# 2        北京-海淀区  六险一金 餐饮补贴 交通补贴 专业培训 年终奖金 班次津贴      10-14
# 3        上海-静安区           五险一金 补充公积金 节日福利 定期体检      10-14
# 4            天津                            NaN      10-14
#
#                      attribute_text
# 0       ['北京-朝阳区', '5-7年经验', '招1人']
# 1     ['深圳', '3-4年经验', '本科', '招1人']
# 2   ['北京-海淀区', '1年经验', '本科', '招8人']
# 3  ['上海-静安区', '无需经验', '本科', '招若干人']
# 4     ['天津', '5-7年经验', '大专', '招1人']

# %%
job.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2500 entries, 0 to 2499
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   job_name            2500 non-null   object
#  1   company_name        2500 non-null   object
#  2   companytype_text    2500 non-null   object
#  3   providesalary_text  2496 non-null   object
#  4   workarea_text       2500 non-null   object
#  5   jobwelf             2083 non-null   object
#  6   updatedate          2500 non-null   object
#  7   attribute_text      2500 non-null   object
# dtypes: object(8)
# memory usage: 156.4+ KB

# %% [markdown]
# ## 数据清洗

# %%
# 删除薪资为空的数据
null_index = job[job.providesalary_text.isnull()].index

# %%
job.drop(null_index, inplace=True)

# %%
job.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2496 entries, 2 to 2499
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   job_name            2496 non-null   object
#  1   company_name        2496 non-null   object
#  2   companytype_text    2496 non-null   object
#  3   providesalary_text  2496 non-null   object
#  4   workarea_text       2496 non-null   object
#  5   jobwelf             2082 non-null   object
#  6   updatedate          2496 non-null   object
#  7   attribute_text      2496 non-null   object
# dtypes: object(8)
# memory usage: 175.5+ KB

# %%
job.reset_index(inplace=True)

# %%
job.providesalary_text.unique()

# %%
# 删除异常值（有几个数据薪资是以日/小时、天/每小时计算的，需要删除）
delete_index = []
for i, salary in enumerate(job.providesalary_text.tolist()):
    if salary.endswith('天') or salary.endswith('小时'):
        delete_index.append(i)
delete_index
# Out:
# [880, 1902, 2047, 2052, 2251, 2371]

# %%
job.iloc[delete_index, :]
# Out:
#       index         job_name      company_name companytype_text  \
# 880     884     运营助理（***，实习）      上海风许网络科技有限公司             民营公司
# 1902   1906  客服专员（调度team）深夜班    建顺信息科技（广州）有限公司          外资（非欧美）
# 2047   2051             产品修图       成都部落窝科技有限公司             民营公司
# 2052   2056         电商平台上架产品      珠海市鲜茗叶茶业有限公司             创业公司
# 2251   2255           天猫直播客服  优盘联队（苏州）电子商务有限公司             民营公司
# 2371   2375             售前客服              极易电商             民营公司
#
#      providesalary_text workarea_text                        jobwelf  \
# 880              150元/天        上海-闵行区  五险一金 交通补贴 餐饮补贴 专业培训 年终奖金 弹性工作
# 1902             26元/小时        广州-天河区                      弹性工作 专业培训
# 2047            120元/小时        成都-成华区                      绩效奖金 弹性工作
# 2052             110元/天        中山-坦洲镇                            NaN
# 2251             25元/小时       苏州-工业园区                            NaN
# 2371             120元/天        苏州-吴中区       五险一金 员工旅游 绩效奖金 弹性工作 定期体检
#
#      updatedate                    attribute_text
# 880       10-14   ['上海-闵行区', '无需经验', '大专', '招2人']
# 1902      10-14   ['广州-天河区', '无需经验', '中专', '招2人']
# 2047      10-14   ['成都-成华区', '2年经验', '大专', '招2人']
# 2052      10-14         ['中山-坦洲镇', '无需经验', '招1人']
# 2251      10-14  ['苏州-工业园区', '无需经验', '高中', '招5人']
# 2371      10-14        ['苏州-吴中区', '无需经验', '招40人']

# %%
job.drop(delete_index, inplace=True)

# %% [markdown]
# ## 数据预处理

# %%
# 添加省份列
job['province'] = job.workarea_text.apply(lambda x: x.split('-')[0])

# %%
# 读取省份城市对照表
province_city = pd.read_csv('data/province_city.csv')
province_city[' 城市'] = province_city[' 城市'].apply(lambda x: x.lstrip(' '))

# %%
province_city.rename(columns={'省份': '省份', ' 城市': '城市'}, inplace=True)

# %%
province_city_dict = dict(zip(province_city['城市'].tolist(),province_city['省份'].tolist()))

# %%
# 将城市替换为对应省份
def replace_province(x):
    if x.endswith('省') or x in ['北京', '上海', '重庆', '天津']:
        return x
    else:
        return province_city_dict[x]

# %%
job['province'] = job.province.apply(replace_province)

# %%
def handle_province(x):
    if x.endswith('省'):
        return x.rstrip('省')
    else:
        return x

# %%
# 处理省份列
job.province = job.province.apply(handle_province)

# %%
job.head()
# Out:
#    index    job_name          company_name companytype_text  \
# 0      2     策略专员-账号          腾讯科技（北京）有限公司             民营公司
# 1      3        销售助理                  新浪上海               合资
# 2      4        城市经理                    美团             上市公司
# 3      5  国企高薪诚聘电子商务  太平洋保险在线服务科技有限公司山东分公司               国企
# 4      6      市场营销经理                    网易             上市公司
#
#   providesalary_text workarea_text  \
# 0             1-2万/月        北京-海淀区
# 1             6-8千/月        上海-静安区
# 2           3-4.5万/月            天津
# 3             4-8千/月            淄博
# 4           2-3.5万/月       上海-浦东新区
#
#                                              jobwelf updatedate  \
# 0                      六险一金 餐饮补贴 交通补贴 专业培训 年终奖金 班次津贴      10-14
# 1                               五险一金 补充公积金 节日福利 定期体检      10-14
# 2                                                NaN      10-14
# 3  五险一金 交通补贴 餐饮补贴 年终奖金 绩效奖金 企业年金 商业保险 周末双休 职工餐厅 带薪培训      10-14
# 4               五险一金 包吃 包三餐 带薪年假 交通补贴 定期体检 商业保险 年终奖金      10-14
#
#                        attribute_text province  salary
# 0     ['北京-海淀区', '1年经验', '本科', '招8人']       北京    15.0
# 1    ['上海-静安区', '无需经验', '本科', '招若干人']       上海     7.0
# 2       ['天津', '5-7年经验', '大专', '招1人']       天津    37.5
# 3        ['淄博', '无需经验', '大专', '招20人']       山东     6.0
# 4  ['上海-浦东新区', '5-7年经验', '本科', '招1人']       上海    27.5

# %%
# 处理薪资列
def handle_salary(x):
    min_salary, max_salary = float(x.split('-')[0]), float(x.split('-')[1][:-3])
    if x.split('-')[1].endswith('万/月'):
        min_salary *= 10
        max_salary *= 10
    return (min_salary + max_salary) / 2

# %%
# 添加岗位平均薪资列
job['salary'] = job.providesalary_text.apply(handle_salary)

# %%
temp = job.province.value_counts()
temp = temp.reset_index()
temp
# Out:
#    index  province
# 0     广东      1084
# 1     上海       369
# 2     浙江       242
# 3     江苏       197
# 4     湖北       116
# 5     四川        90
# 6     北京        53
# 7     湖南        48
# 8     安徽        42
# 9     河南        32
# 10    山东        32
# 11    重庆        30
# 12    云南        28
# 13    陕西        28
# 14    福建        23
# 15    江西        21
# 16    天津        14
# 17    辽宁        14
# 18    河北         6
# 19    广西         5
# 20    吉林         4
# 21    贵州         3
# 22   内蒙古         2
# 23    海南         2
# 24   黑龙江         2
# 25    新疆         1
# 26    甘肃         1
# 27    青海         1

# %% [markdown]
# ## 数据透视和可视化

# %% [markdown]
# ### 岗位标题词云

# %%
# 读入停用词
with open('data/stopword.txt', 'r', encoding='utf-8') as file:
    stopword_list = [word.strip('\n') for word in file.readlines()]

# %%
import jieba

content = ''.join(job['job_name'])
# 分词
words = jieba.lcut(content)
words = [word for word in words if word not in stopword_list]

# %%
# 绘制词云图
from wordcloud import WordCloud
from PIL import Image

txt = ' '.join(words)
mask = np.array(Image.open('image/China_map.jpg'))
# 创建词云对象
wc = WordCloud(
    font_path='font/SimHei.ttf',
    mask=mask,
    width=1200,
    height=800,
    background_color='white',
    max_words=100
)
wc.generate(txt)
wc.to_file('result1.png')

# %% [markdown]
# <img src="result1.png">

# %% [markdown]
# ### 岗位热力地图

# %%
from pyecharts import options as opts
from pyecharts.charts import Map
from pyecharts.faker import Faker
from pyecharts.globals import ThemeType

pieces = [
    {"min": 0, "max": 30},
    {"min": 30, "max": 60},
    {"min": 60, "max": 100},
    {"min": 100, "max": 150},
    {"min": 150, "max": 300},
    {"min": 300, "max": 400},
    {"min": 400}
]


map = Map(init_opts=opts.InitOpts(theme=ThemeType.WONDERLAND))
map.add("", [list(z) for z in zip(list(temp['index']), list(temp['province']))], "china")
map.set_global_opts(
    title_opts=opts.TitleOpts(title="岗位地区分布"),
    visualmap_opts=opts.VisualMapOpts(max_=400,
                                      is_piecewise=True,
                                     pieces=pieces),
)

map.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'china':'https://assets.pyecharts.org/assets/maps/china', 'wonderland':'https://assets.pyecharts.org/assets/themes/wonderland'
#         }
#     });
# </script>
#
#         <div id="21da2957e67b44509add0f5ef91d0ead" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'china', 'wonderland'], function(echarts) {
#                 var chart_21da2957e67b44509add0f5ef91d0ead = echarts.init(
#                     document.getElementById('21da2957e67b44509add0f5ef91d0ead'), 'wonderland', {renderer: 'canvas'});
#                 var option_21da2957e67b44509add0f5ef91d0ead = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "series": [
#         {
#             "type": "map",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "mapType": "china",
#             "data": [
#                 {
#                     "name": "\u5e7f\u4e1c",
#                     "value": 1084
#                 },
#                 {
#                     "name": "\u4e0a\u6d77",
#                     "value": 369
#                 },
#                 {
#                     "name": "\u6d59\u6c5f",
#                     "value": 242
#                 },
#                 {
#                     "name": "\u6c5f\u82cf",
#                     "value": 197
#                 },
#                 {
#                     "name": "\u6e56\u5317",
#                     "value": 116
#                 },
#                 {
#                     "name": "\u56db\u5ddd",
#                     "value": 90
#                 },
#                 {
#                     "name": "\u5317\u4eac",
#                     "value": 53
#                 },
#                 {
#                     "name": "\u6e56\u5357",
#                     "value": 48
#                 },
#                 {
#                     "name": "\u5b89\u5fbd",
#                     "value": 42
#                 },
#                 {
#                     "name": "\u6cb3\u5357",
#                     "value": 32
#                 },
#                 {
#                     "name": "\u5c71\u4e1c",
#                     "value": 32
#                 },
#                 {
#                     "name": "\u91cd\u5e86",
#                     "value": 30
#                 },
#                 {
#                     "name": "\u4e91\u5357",
#                     "value": 28
#                 },
#                 {
#                     "name": "\u9655\u897f",
#                     "value": 28
#                 },
#                 {
#                     "name": "\u798f\u5efa",
#                     "value": 23
#                 },
#                 {
#                     "name": "\u6c5f\u897f",
#                     "value": 21
#                 },
#                 {
#                     "name": "\u5929\u6d25",
#                     "value": 14
#                 },
#                 {
#                     "name": "\u8fbd\u5b81",
#                     "value": 14
#                 },
#                 {
#                     "name": "\u6cb3\u5317",
#                     "value": 6
#                 },
#                 {
#                     "name": "\u5e7f\u897f",
#                     "value": 5
#                 },
#                 {
#                     "name": "\u5409\u6797",
#                     "value": 4
#                 },
#                 {
#                     "name": "\u8d35\u5dde",
#                     "value": 3
#                 },
#                 {
#                     "name": "\u5185\u8499\u53e4",
#                     "value": 2
#                 },
#                 {
#                     "name": "\u6d77\u5357",
#                     "value": 2
#                 },
#                 {
#                     "name": "\u9ed1\u9f99\u6c5f",
#                     "value": 2
#                 },
#                 {
#                     "name": "\u65b0\u7586",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u7518\u8083",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u9752\u6d77",
#                     "value": 1
#                 }
#             ],
#             "roam": true,
#             "aspectScale": 0.75,
#             "nameProperty": "name",
#             "selectedMode": false,
#             "zoom": 1,
#             "mapValueCalculation": "sum",
#             "showLegendSymbol": true,
#             "emphasis": {}
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selected": {
#                 "": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "title": [
#         {
#             "text": "\u5c97\u4f4d\u5730\u533a\u5206\u5e03",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ],
#     "visualMap": {
#         "show": true,
#         "type": "piecewise",
#         "min": 0,
#         "max": 400,
#         "inRange": {
#             "color": [
#                 "#50a3ba",
#                 "#eac763",
#                 "#d94e5d"
#             ]
#         },
#         "calculable": true,
#         "inverse": false,
#         "splitNumber": 5,
#         "orient": "vertical",
#         "showLabel": true,
#         "itemWidth": 20,
#         "itemHeight": 14,
#         "borderWidth": 0,
#         "pieces": [
#             {
#                 "min": 0,
#                 "max": 30
#             },
#             {
#                 "min": 30,
#                 "max": 60
#             },
#             {
#                 "min": 60,
#                 "max": 100
#             },
#             {
#                 "min": 100,
#                 "max": 150
#             },
#             {
#                 "min": 150,
#                 "max": 300
#             },
#             {
#                 "min": 300,
#                 "max": 400
#             },
#             {
#                 "min": 400
#             }
#         ]
#     }
# };
#                 chart_21da2957e67b44509add0f5ef91d0ead.setOption(option_21da2957e67b44509add0f5ef91d0ead);
#         });
#     </script>

# %%
# 省份平均薪资Top-10
temp = pd.pivot_table(job, index='province', values='salary', aggfunc='mean').nlargest(10, 'salary')
temp = temp.applymap(lambda x: round(x, 2))

# %%
from pyecharts import options as opts
from pyecharts.charts import Bar


b = Bar()
b.add_xaxis(
    temp.index.tolist()
)
b.add_yaxis("", temp.salary.tolist())

b.set_global_opts(
    title_opts=opts.TitleOpts(title="省份平均薪资Top-10", subtitle=""),
    yaxis_opts=opts.AxisOpts(
            name="平均薪资",
            type_="value",
            min_=0,
            max_=15,
            interval=3,
            axislabel_opts=opts.LabelOpts(formatter="{value} k"),
            axistick_opts=opts.AxisTickOpts(is_show=True),
            splitline_opts=opts.SplitLineOpts(is_show=True),
        ),
)
b.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="b190e92260474b5985a7c20f555dda66" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_b190e92260474b5985a7c20f555dda66 = echarts.init(
#                     document.getElementById('b190e92260474b5985a7c20f555dda66'), 'white', {renderer: 'canvas'});
#                 var option_b190e92260474b5985a7c20f555dda66 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "legendHoverLink": true,
#             "data": [
#                 14.66,
#                 12.71,
#                 11.67,
#                 10.25,
#                 9.88,
#                 9.79,
#                 9.72,
#                 9.7,
#                 9.53,
#                 9.47
#             ],
#             "showBackground": false,
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selected": {
#                 "": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u5317\u4eac",
#                 "\u4e0a\u6d77",
#                 "\u8d35\u5dde",
#                 "\u5e7f\u4e1c",
#                 "\u9ed1\u9f99\u6c5f",
#                 "\u6d59\u6c5f",
#                 "\u6c5f\u82cf",
#                 "\u5929\u6d25",
#                 "\u5b89\u5fbd",
#                 "\u6c5f\u897f"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "type": "value",
#             "name": "\u5e73\u5747\u85aa\u8d44",
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "interval": 3,
#             "gridIndex": 0,
#             "axisTick": {
#                 "show": true,
#                 "alignWithLabel": false,
#                 "inside": false
#             },
#             "axisLabel": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8,
#                 "formatter": "{value} k"
#             },
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "min": 0,
#             "max": 15,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "\u7701\u4efd\u5e73\u5747\u85aa\u8d44Top-10",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_b190e92260474b5985a7c20f555dda66.setOption(option_b190e92260474b5985a7c20f555dda66);
#         });
#     </script>

# %%
# 前五位公司聚集地
temp = pd.pivot_table(job, index='province', values='companytype_text', aggfunc='count')
temp = temp.nlargest(5, columns='companytype_text')
temp
# Out:
#           companytype_text
# province
# 广东                    1084
# 上海                     369
# 浙江                     242
# 江苏                     197
# 湖北                     116

# %%
temp1 = job.loc[job['province'].isin(temp.index.tolist())]

# %%
temp = pd.pivot_table(temp1, index='province', columns='companytype_text', values='company_name', aggfunc='count')
temp.fillna(0, inplace=True)
temp
# Out:
# companytype_text  上市公司  事业单位  创业公司    合资    国企  外企代表处  外资（欧美）  外资（非欧美）   民营公司  \
# province
# 上海                21.0   0.0   4.0  26.0   6.0    1.0    11.0     20.0  280.0
# 广东                28.0   1.0  33.0  28.0  11.0    1.0    13.0     30.0  938.0
# 江苏                 9.0   0.0   4.0  13.0   5.0    0.0     6.0      6.0  154.0
# 浙江                 4.0   0.0   7.0   3.0   1.0    0.0     3.0      5.0  219.0
# 湖北                 7.0   0.0   3.0   1.0   3.0    0.0     2.0      3.0   97.0
#
# companytype_text  非营利组织
# province
# 上海                  0.0
# 广东                  1.0
# 江苏                  0.0
# 浙江                  0.0
# 湖北                  0.0

# %%
temp = temp.div(temp.sum(axis=1), axis=0)
temp = temp.applymap(lambda x: round(x, 3))

# %%
temp
# Out:
# companytype_text   上市公司   事业单位   创业公司     合资     国企  外企代表处  外资（欧美）  外资（非欧美）  \
# province
# 上海                0.057  0.000  0.011  0.070  0.016  0.003   0.030    0.054
# 广东                0.026  0.001  0.030  0.026  0.010  0.001   0.012    0.028
# 江苏                0.046  0.000  0.020  0.066  0.025  0.000   0.030    0.030
# 浙江                0.017  0.000  0.029  0.012  0.004  0.000   0.012    0.021
# 湖北                0.060  0.000  0.026  0.009  0.026  0.000   0.017    0.026
#
# companytype_text   民营公司  非营利组织
# province
# 上海                0.759  0.000
# 广东                0.865  0.001
# 江苏                0.782  0.000
# 浙江                0.905  0.000
# 湖北                0.836  0.000

# %% [markdown]
# ### 前五位公司聚集地各类型公司发展情况

# %%
d = Bar()
d.add_xaxis(temp.index.tolist())
for index, i in enumerate(temp.columns):
    d.add_yaxis(temp.columns[index], temp[i].tolist(), stack="stack1")
d.set_series_opts(label_opts=opts.LabelOpts(is_show=False))
d.set_global_opts(title_opts=opts.TitleOpts(title=""))
d.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="d0886295b7444b9db5d3399d940b2ee3" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_d0886295b7444b9db5d3399d940b2ee3 = echarts.init(
#                     document.getElementById('d0886295b7444b9db5d3399d940b2ee3'), 'white', {renderer: 'canvas'});
#                 var option_d0886295b7444b9db5d3399d940b2ee3 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u4e0a\u5e02\u516c\u53f8",
#             "legendHoverLink": true,
#             "data": [
#                 0.057,
#                 0.026,
#                 0.046,
#                 0.017,
#                 0.06
#             ],
#             "showBackground": false,
#             "stack": "stack1",
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u4e8b\u4e1a\u5355\u4f4d",
#             "legendHoverLink": true,
#             "data": [
#                 0.0,
#                 0.001,
#                 0.0,
#                 0.0,
#                 0.0
#             ],
#             "showBackground": false,
#             "stack": "stack1",
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u521b\u4e1a\u516c\u53f8",
#             "legendHoverLink": true,
#             "data": [
#                 0.011,
#                 0.03,
#                 0.02,
#                 0.029,
#                 0.026
#             ],
#             "showBackground": false,
#             "stack": "stack1",
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u5408\u8d44",
#             "legendHoverLink": true,
#             "data": [
#                 0.07,
#                 0.026,
#                 0.066,
#                 0.012,
#                 0.009
#             ],
#             "showBackground": false,
#             "stack": "stack1",
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u56fd\u4f01",
#             "legendHoverLink": true,
#             "data": [
#                 0.016,
#                 0.01,
#                 0.025,
#                 0.004,
#                 0.026
#             ],
#             "showBackground": false,
#             "stack": "stack1",
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u5916\u4f01\u4ee3\u8868\u5904",
#             "legendHoverLink": true,
#             "data": [
#                 0.003,
#                 0.001,
#                 0.0,
#                 0.0,
#                 0.0
#             ],
#             "showBackground": false,
#             "stack": "stack1",
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u5916\u8d44\uff08\u6b27\u7f8e\uff09",
#             "legendHoverLink": true,
#             "data": [
#                 0.03,
#                 0.012,
#                 0.03,
#                 0.012,
#                 0.017
#             ],
#             "showBackground": false,
#             "stack": "stack1",
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         },
#         {
#             "type"
